# %%
from data import *
from utilities import *

training_images = get_training_data()
training_labels = get_training_labels()
test_images = get_test_data()
test_labels = get_test_labels()

# %%
# Examples from the dataset

view_image(training_images[0])
view_image(training_images[23698])
view_image(training_images[49321])

view_image(test_images[236])
view_image(test_images[3678])
view_image(test_images[8963])

# %%
# Look at the distribution of the training images

import matplotlib.pyplot as plt

plt.hist(training_labels, bins=10)
plt.gca().set(title='Training Images');

# %%
print(np.bincount(training_labels))
# Out:
# [5923 6742 5958 6131 5842 5421 5918 6265 5851 5949]

# %%
plt.hist(test_labels, bins=10)
plt.gca().set(title='Test Images');

# %%
print(np.bincount(test_labels))
# Out:
# [ 980 1135 1032 1010  982  892  958 1028  974 1009]
